# %% [markdown]
# <a href="https://colab.research.google.com/github/seung12345/project/blob/main/Dog_Classification_Service.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt install fonts-nanum -y

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 한글 폰트 설정하기
fontpath= '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font= fm.FontProperties(fname=fontpath, size=10)
plt.rc('font', family='NanumBarunGothic')
matplotlib.font_manager._rebuild()
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
# !git clone https://github.com/ndb796/bing_image_downloader
# Out:
# fatal: destination path 'bing_image_downloader' already exists and is not an empty directory.

# %%
import os
import shutil
from bing_image_downloader.bing_image_downloader import downloader

directory_list =[
                 './custom_dataset/train/',
                 './custom_dataset/test',
]
# 초기 디렉토리 만들기
for directory in directory_list:
  if not os.path.isdir(directory):
    os.makedirs(directory)

# 수집한 이미지를 학습 데이터와 평가 데이터로 구분하는 함수
def dataset_split(query, train_cnt):
  # 학습 및 평가 데이터셋 디렉토리 만들기  
  for directory in directory_list:
    if not os.path.isdir(directory + '/' + query):
      os.makedirs(directory +'/'+query)
  # 학습 및 평가 데이터셋 준비하기    
  cnt=0
  for file_name in os.listdir(query):
    if cnt<train_cnt:
      print(f'[Train Dataset] {file_name}')
      shutil.move(query+ '/' +file_name, './custom_dataset/train/' +query +'/' + file_name)
    else:
      print(f'[Test Dataset] {file_name}')
      shutil.move(query + '/' +file_name, './custom_dataset/test/' + query + '/' +file_name)
    cnt+=1
  shutil.rmtree(query)

# %%
query='시츄'
downloader.download(query, limit=40, output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query,30)
# Out:
# [Info] Indexing page: 1
# [Info] Indexed 40 Images on Page 1.
# ===============================================
# #1 이미지 다운로드 (https://i.ytimg.com/vi/E1QWkeiPSyM/maxresdefault.jpg)
# #1 파일 다운로드가 완료되었습니다.
# #2 이미지 다운로드 (https://i.pinimg.com/originals/1b/1f/29/1b1f299aacf0fd714d5e34cdb3388eab.jpg)
# #2 파일 다운로드가 완료되었습니다.
# #3 이미지 다운로드 (https://cdn.imweb.me/upload/S201805185afe0684ef3d8/9d205c6781cca.jpg)
# #3 파일 다운로드가 완료되었습니다.
# #4 이미지 다운로드 (http://cfile240.uf.daum.net/image/246C5D4052C8D5971FE071)
# #4 파일 다운로드가 완료되었습니다.
# #5 이미지 다운로드 (http://i.ytimg.com/vi/9ce_nlTJp6Y/maxresdefault.jpg)
# #5 파일 다운로드가 완료되었습니다.
# #6 이미지 다운로드 (http://blogthumb2.naver.net/20160527_18/qpapp_1464331854784RrM7f_PNG/1.png?type=w2)
# #6 파일 다운로드가 완료되었습니다.
# #7 이미지 다운로드 (http://t1.daumcdn.net/liveboard/petnu/24a551064072463a8603bc05a168cdb0.JPG)
# #7 파일 다운로드가 완료되었습니다.
# #8 이미지 다운로드 (http://cfile208.uf.daum.net/image/2128AA4D5699AC0808F589)
# #8 파일 다운로드가 완료되었습니다.
# #9 이미지 다운로드 (https://cdn.imweb.me/upload/S201805185afe0684ef3d8/9c50b39ac5cb6.jpg)
# #9 파일 다운로드가 완료되었습니다.
# #10 이미지 다운로드 (https://i.ytimg.com/vi/W5qL8juvAdQ/maxresdefault.jpg)
# #10 파일 다운로드가 완료되었습니다.
# #11 이미지 다운로드 (https://i.ytimg.com/vi/v_MeFyVTNm4/maxresdefault.jpg)
# #11 파일 다운로드가 완료되었습니다.
# #12 이미지 다운로드 (http://t1.daumcdn.net/liveboard/petnu/bfafbb84eb154df3801252e63843a831.JPG)
# #12 파일 다운로드가 완료되었습니다.
# #13 이미지 다운로드 (http://cfile203.uf.daum.net/image/2449143E52A0B9970FA018)
# #13 파일 다운로드가 완료되었습니다.
# #14 이미지 다운로드 (https://i.ytimg.com/vi/ERB6BL_RIIU/maxresdefault.jpg)
# #14 파일 다운로드가 완료되었습니다.
# #15 이미지 다운로드 (https://dimg.donga.com/wps/ECONOMY/IMAGE/2013/12/30/59864097.1.jpg)
# #15 파일 다운로드가 완료되었습니다.
# #16 이미지 다운로드 (http://cfile201.uf.daum.net/image/212DF04A55027B701B7111)
# #16 파일 다운로드가 완료되었습니다.
# #17 이미지 다운로드 (https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F263E434851BECB5E18)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F263E434851BECB5E18
# [Error] HTTP Error 403: Forbidden
# #17 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/993B023359B140DA17)
# #17 파일 다운로드가 완료되었습니다.
# #18 이미지 다운로드 (http://cfile214.uf.daum.net/image/20135D484EA135CE0C9B76)
# #18 파일 다운로드가 완료되었습니다.
# #19 이미지 다운로드 (https://post-phinf.pstatic.net/MjAxNzA3MDdfMjE4/MDAxNDk5NDEzMTczMzgx.NVeFxXzIR0O7YA7OJDh36cjgk8AmxppdtZIp-Gkr2S0g.82T-oUOsTY7Xcdu0BD5GeeOr0ipL0gkPoL2g7RE5A1wg.JPEG/Iv8C_AFkIn-Hfww1mw-o4f5Cs9Qk.jpg?type=w400)
# #19 파일 다운로드가 완료되었습니다.
# #20 이미지 다운로드 (http://petfamily.itpage.kr/user/p/petfamily/editor/1804/thumb-6e0550a4bffc3343c9a894aa5a03c0c4_1523184866_4907_600x540.jpg)
# #20 파일 다운로드가 완료되었습니다.
# #21 이미지 다운로드 (http://cfile7.uf.tistory.com/image/210F555057E0F992369A2C)
# #21 파일 다운로드가 완료되었습니다.
# #22 이미지 다운로드 (https://i.pinimg.com/originals/26/80/4d/26804d91bde1f11ae7d2e10d510c4b01.jpg)
# #22 파일 다운로드가 완료되었습니다.
# #23 이미지 다운로드 (https://singlesumer.com/files/attach/images/141/753/042/46a4061f43e66868f8b43999f7634493.JPG)
# #23 파일 다운로드가 완료되었습니다.
# #24 이미지 다운로드 (https://fimg2.pann.com/new/download.jsp?FileID=25291285)
# #24 파일 다운로드가 완료되었습니다.
# #25 이미지 다운로드 (http://www.zooseyo.or.kr/pet_care/photo/1567835950_54526900.jpg)
# #25 파일 다운로드가 완료되었습니다.
# #26 이미지 다운로드 (https://pbs.twimg.com/media/CY2aA7YWkAAhz0j.jpg)
# #26 파일 다운로드가 완료되었습니다.
# #27 이미지 다운로드 (http://postfiles6.naver.net/20160315_21/ifthey_1458010021211vFRet_JPEG/DSC04348.jpg?type=w2)
# #27 파일 다운로드가 완료되었습니다.
# #28 이미지 다운로드 (http://postfiles2.naver.net/20141124_1/ifthey_1416819726696lfbUe_JPEG/DSC07526-1.jpg?type=w2)
# #28 파일 다운로드가 완료되었습니다.
# #29 이미지 다운로드 (http://blogthumb2.naver.net/20141124_60/ifthey_1416819377164pEN28_JPEG/DSC07533-1.jpg?type=w2)
# [Error] Invalid image, not saving http://blogthumb2.naver.net/20141124_60/ifthey_1416819377164pEN28_JPEG/DSC07533-1.jpg?type=w2
# [Info] Issue getting: http://blogthumb2.naver.net/20141124_60/ifthey_1416819377164pEN28_JPEG/DSC07533-1.jpg?type=w2
# [Error] No active exception to reraise
# #29 이미지 다운로드 (http://cfile23.uf.tistory.com/image/273B1A4851FF25D501B266)
# #29 파일 다운로드가 완료되었습니다.
# #30 이미지 다운로드 (https://i.pinimg.com/originals/cb/6b/b0/cb6bb00860fa9eaa2665b28405645d2d.jpg)
# #30 파일 다운로드가 완료되었습니다.
# #31 이미지 다운로드 (https://i.ytimg.com/vi/6VYO4JmoJKY/maxresdefault.jpg)
# #31 파일 다운로드가 완료되었습니다.
# #32 이미지 다운로드 (https://i.ytimg.com/vi/lbXtaPDdOLk/maxresdefault.jpg)
# #32 파일 다운로드가 완료되었습니다.
# #33 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/222CE45057E0F99212)
# #33 파일 다운로드가 완료되었습니다.
# #34 이미지 다운로드 (http://cfile27.uf.tistory.com/image/25740442537AB9E721B7A4)
# #34 파일 다운로드가 완료되었습니다.
# #35 이미지 다운로드 (http://cfile29.uf.tistory.com/image/26260A4551BA832D2D5922)
# #35 파일 다운로드가 완료되었습니다.
# #36 이미지 다운로드 (https://i.pinimg.com/originals/f5/d3/d9/f5d3d97ef5bcda29c475cf121f34dfb6.jpg)
# #36 파일 다운로드가 완료되었습니다.
# #37 이미지 다운로드 (http://cfs12.blog.daum.net/image/17/blog/2008/02/23/23/37/47c02f428e2bf)
# #37 파일 다운로드가 완료되었습니다.
# #38 이미지 다운로드 (https://singlesumer.com/files/attach/images/141/496/049/570579c9bd47ec6d273f0e5a23608393.jpeg)
# #38 파일 다운로드가 완료되었습니다.
# [Info] Done. Downloaded 38 images.
# [Info] Indexing page: 2
# [Info] Indexed 35 Images on Page 2.
# ===============================================
# #39 이미지 다운로드 (https://i.ytimg.com/vi/E1QWkeiPSyM/maxresdefault.jpg)
# #39 파일 다운로드가 완료되었습니다.
# #40 이미지 다운로드 (https://i.pinimg.com/originals/1b/1f/29/1b1f299aacf0fd714d5e34cdb3388eab.jpg)
# #40 파일 다운로드가 완료되었습니다.
# ===============================================
# [Info] Done. Downloaded 40 images.
# [Train Dataset] image_32.jpg
# [Train Dataset] image_11.jpg
# [Train Dataset] image_34.jpg
# [Train Dataset] image_30.jpg
# [Train Dataset] image_27.jpg
# [Train Dataset] image_16.jpg
# [Train Dataset] image_10.jpg
# [Train Dataset] image_1.jpg
# [Train Dataset] image_21.jpg
# [Train Dataset] image_23.JPG
# [Train Dataset] image_33.jpg
# [Train Dataset] image_31.jpg
# [Train Dataset] image_20.jpg
# [Train Dataset] image_39.jpg
# [Train Dataset] image_4.jpg
# [Train Dataset] image_29.jpg
# [Train Dataset] image_37.jpg
# [Train Dataset] image_7.JPG
# [Train Dataset] image_38.jpeg
# [Train Dataset] image_15.jpg
# [Train Dataset] image_28.jpg
# [Train Dataset] image_5.jpg
# [Train Dataset] image_25.jpg
# [Train Dataset] image_12.JPG
# [Train Dataset] image_13.jpg
# [Train Dataset] image_26.jpg
# [Train Dataset] image_19.jpg
# [Train Dataset] image_22.jpg
# [Train Dataset] image_40.jpg
# [Train Dataset] image_35.jpg
# [Test Dataset] image_36.jpg
# [Test Dataset] image_6.png
# [Test Dataset] image_14.jpg
# [Test Dataset] image_3.jpg
# [Test Dataset] image_8.jpg
# [Test Dataset] image_18.jpg
# [Test Dataset] image_2.jpg
# [Test Dataset] image_9.jpg
# [Test Dataset] image_24.jpg
# [Test Dataset] image_17.jpg

# %%
query='말티즈'
downloader.download(query, limit=40, output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query,30)
# Out:
# [Info] Indexing page: 1
# [Info] Indexed 40 Images on Page 1.
# ===============================================
# #1 이미지 다운로드 (http://t1.daumcdn.net/liveboard/petnu/e5540d8c024544ad940d96dbce78a152.JPG)
# #1 파일 다운로드가 완료되었습니다.
# #2 이미지 다운로드 (https://i.smalljoys.me/2019/04/3-34.jpg)
# #2 파일 다운로드가 완료되었습니다.
# #3 이미지 다운로드 (https://tistory1.daumcdn.net/tistory/4287155/attach/d36d1080898a4123bf63ff3ca627ac20)
# #3 파일 다운로드가 완료되었습니다.
# #4 이미지 다운로드 (https://img.animalplanet.co.kr/news/2020/07/24/700/jd4w24cl550bkk2dvrh7.jpg)
# #4 파일 다운로드가 완료되었습니다.
# #5 이미지 다운로드 (http://t1.daumcdn.net/liveboard/petnu/269137753ee445cc9fc9308d3defc8d8.JPG)
# #5 파일 다운로드가 완료되었습니다.
# #6 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/99AA67405B213AAC30)
# #6 파일 다운로드가 완료되었습니다.
# #7 이미지 다운로드 (http://t1.daumcdn.net/liveboard/petnu/e9bccd294d5b4632a8eb7e7906bcd05a.JPG)
# #7 파일 다운로드가 완료되었습니다.
# #8 이미지 다운로드 (https://fimg3.pann.com/new/download.jsp?FileID=33213744)
# #8 파일 다운로드가 완료되었습니다.
# #9 이미지 다운로드 (http://fimg3.pann.com/new/download.jsp?FileID=36075235)
# #9 파일 다운로드가 완료되었습니다.
# #10 이미지 다운로드 (https://img.animalplanet.co.kr/thumbnail/2019/09/26/2000/hm322l1ge1i39a59rdd7.jpg)
# #10 파일 다운로드가 완료되었습니다.
# #11 이미지 다운로드 (http://postfiles5.naver.net/20161019_20/miosolkim_1476842879392W9Fmu_JPEG/FB_IMG_1438543301010_2.jpg?type=w1)
# #11 파일 다운로드가 완료되었습니다.
# #12 이미지 다운로드 (https://img.animalplanet.co.kr/thumbnail/2020/09/19/2000/88lnq6j9rls168mho2xu.jpg)
# #12 파일 다운로드가 완료되었습니다.
# #13 이미지 다운로드 (http://t1.daumcdn.net/liveboard/petnu/ec7fb455cc2e44f2b1507703e80da6d0.JPG)
# #13 파일 다운로드가 완료되었습니다.
# #14 이미지 다운로드 (https://cdn.imweb.me/upload/S201805185afe0684ef3d8/b6c1fc647bc91.jpg)
# #14 파일 다운로드가 완료되었습니다.
# #15 이미지 다운로드 (http://i.ytimg.com/vi/A7t_sb9ZaY8/maxresdefault.jpg)
# #15 파일 다운로드가 완료되었습니다.
# #16 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/9947C93B5CC04A1415)
# #16 파일 다운로드가 완료되었습니다.
# #17 이미지 다운로드 (https://img.animalplanet.co.kr/thumbnail/2020/03/14/2000/f3t93041s0cqz5o0c18u.jpg)
# #17 파일 다운로드가 완료되었습니다.
# #18 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/234D185058D611ED2F)
# #18 파일 다운로드가 완료되었습니다.
# #19 이미지 다운로드 (http://cfile9.uf.tistory.com/image/2128DE4354FE7152302976)
# #19 파일 다운로드가 완료되었습니다.
# #20 이미지 다운로드 (https://cdn.imweb.me/upload/S201805185afe0684ef3d8/5ccc2760a22a0.jpg)
# #20 파일 다운로드가 완료되었습니다.
# #21 이미지 다운로드 (https://fimg3.pann.com/new/download.jsp?FileID=33416238)
# #21 파일 다운로드가 완료되었습니다.
# #22 이미지 다운로드 (http://cfile238.uf.daum.net/image/23438D3A50F7536211C2A0)
# #22 파일 다운로드가 완료되었습니다.
# #23 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/994B883B5CC04A1515)
# #23 파일 다운로드가 완료되었습니다.
# #24 이미지 다운로드 (https://i.ytimg.com/vi/v7XDkyCEUas/maxresdefault.jpg)
# #24 파일 다운로드가 완료되었습니다.
# #25 이미지 다운로드 (http://cfile227.uf.daum.net/image/213B3A475465ABB1097254)
# #25 파일 다운로드가 완료되었습니다.
# #26 이미지 다운로드 (https://cdn.imweb.me/upload/S201907024711f2efb4922/8a79de9f88876.jpg)
# #26 파일 다운로드가 완료되었습니다.
# #27 이미지 다운로드 (http://cfile207.uf.daum.net/image/142F084851776F5221C4D5)
# #27 파일 다운로드가 완료되었습니다.
# #28 이미지 다운로드 (https://cdn.imweb.me/upload/S201907024711f2efb4922/32025b679c973.jpg)
# #28 파일 다운로드가 완료되었습니다.
# #29 이미지 다운로드 (http://blogfiles.naver.net/20151225_107/efurqztcqh_1451012925756018sJ_JPEG/%B8%BBƼ%C1%EE%B9̿%EB_(8).jpg)
# [Info] Issue getting: http://blogfiles.naver.net/20151225_107/efurqztcqh_1451012925756018sJ_JPEG/%B8%BBƼ%C1%EE%B9̿%EB_(8).jpg
# [Error] 'ascii' codec can't encode character '\u01bc' in position 59: ordinal not in range(128)
# #29 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/276B444B58D611F917)
# #29 파일 다운로드가 완료되었습니다.
# #30 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/015C9C4151B57ADF28)
# #30 파일 다운로드가 완료되었습니다.
# #31 이미지 다운로드 (https://www.ntdtv.kr/assets/uploads/2019/08/c6029e771edf124edb6ac21da89d3c21-795x436.jpg)
# #31 파일 다운로드가 완료되었습니다.
# #32 이미지 다운로드 (http://img.etoday.co.kr/pto_db/2017/09/20170929101806_1133006_710_340.jpg)
# #32 파일 다운로드가 완료되었습니다.
# #33 이미지 다운로드 (http://sinsadog.com/web/upload/NNEditor/20200106/IMG_5381_shop1_141105.jpg)
# #33 파일 다운로드가 완료되었습니다.
# #34 이미지 다운로드 (https://i.pinimg.com/736x/69/c4/36/69c436bd196a4844e6a8a4dc0690ed8a.jpg)
# #34 파일 다운로드가 완료되었습니다.
# #35 이미지 다운로드 (https://contents.sixshop.com/thumbnails/uploadedFiles/79226/product/image_1576249365188_1000.jpg)
# #35 파일 다운로드가 완료되었습니다.
# #36 이미지 다운로드 (http://cfile215.uf.daum.net/image/2247E34D52319FA10338EE)
# #36 파일 다운로드가 완료되었습니다.
# #37 이미지 다운로드 (https://img.animalplanet.co.kr/news/2020/05/18/700/0311h221h84jzprk1w26.jpg)
# #37 파일 다운로드가 완료되었습니다.
# #38 이미지 다운로드 (https://live.staticflickr.com/4141/4910282602_4001b86eff_b.jpg)
# #38 파일 다운로드가 완료되었습니다.
# #39 이미지 다운로드 (https://contents.sixshop.com/thumbnails/uploadedFiles/79226/product/image_1569170685033_1000.jpg)
# #39 파일 다운로드가 완료되었습니다.
# [Info] Done. Downloaded 39 images.
# [Info] Indexing page: 2
# [Info] Indexed 35 Images on Page 2.
# ===============================================
# #40 이미지 다운로드 (http://t1.daumcdn.net/liveboard/petnu/e5540d8c024544ad940d96dbce78a152.JPG)
# #40 파일 다운로드가 완료되었습니다.
# ===============================================
# [Info] Done. Downloaded 40 images.
# [Train Dataset] image_32.jpg
# [Train Dataset] image_11.jpg
# [Train Dataset] image_1.JPG
# [Train Dataset] image_34.jpg
# [Train Dataset] image_30.jpg
# [Train Dataset] image_23.jpg
# [Train Dataset] image_27.jpg
# [Train Dataset] image_16.jpg
# [Train Dataset] image_10.jpg
# [Train Dataset] image_21.jpg
# [Train Dataset] image_33.jpg
# [Train Dataset] image_31.jpg
# [Train Dataset] image_6.jpg
# [Train Dataset] image_20.jpg
# [Train Dataset] image_39.jpg
# [Train Dataset] image_12.jpg
# [Train Dataset] image_4.jpg
# [Train Dataset] image_29.jpg
# [Train Dataset] image_37.jpg
# [Train Dataset] image_7.JPG
# [Train Dataset] image_15.jpg
# [Train Dataset] image_28.jpg
# [Train Dataset] image_25.jpg
# [Train Dataset] image_26.jpg
# [Train Dataset] image_19.jpg
# [Train Dataset] image_22.jpg
# [Train Dataset] image_35.jpg
# [Train Dataset] image_36.jpg
# [Train Dataset] image_13.JPG
# [Train Dataset] image_14.jpg
# [Test Dataset] image_38.jpg
# [Test Dataset] image_3.jpg
# [Test Dataset] image_5.JPG
# [Test Dataset] image_8.jpg
# [Test Dataset] image_18.jpg
# [Test Dataset] image_40.JPG
# [Test Dataset] image_2.jpg
# [Test Dataset] image_9.jpg
# [Test Dataset] image_24.jpg
# [Test Dataset] image_17.jpg

# %%
query='진돗개'
downloader.download(query, limit=40, output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query,30)
# Out:
# [Info] Indexing page: 1
# [Info] Indexed 40 Images on Page 1.
# ===============================================
# #1 이미지 다운로드 (https://lh3.googleusercontent.com/-NdCcPkRm0lY/W0YBeihxd9I/AAAAAAADAV0/fwD36p2ucp85ciwNT5zDmoaa2wcxKqxrQCHMYCw/s0/068671d19df8a7e6533af3253ada1b27651e7ab6.jpg)
# #1 파일 다운로드가 완료되었습니다.
# #2 이미지 다운로드 (http://5taku.com/uploaded/board/2015/08/26/o_19timah9i7md4pj19n1sqk1sapv.jpg)
# #2 파일 다운로드가 완료되었습니다.
# #3 이미지 다운로드 (https://image.ytn.co.kr/general/jpg/2020/0614/202006141404116144_t.jpg)
# #3 파일 다운로드가 완료되었습니다.
# #4 이미지 다운로드 (https://img1.daumcdn.net/thumb/R720x0/?fname=https:%2F%2Ft1.daumcdn.net%2Fliveboard%2Fholapet%2Fc5ff09c7aa1d48a99554d3442ff8462c.jpg)
# #4 파일 다운로드가 완료되었습니다.
# #5 이미지 다운로드 (http://cfile214.uf.daum.net/image/23071A4851FA943B077270)
# #5 파일 다운로드가 완료되었습니다.
# #6 이미지 다운로드 (https://i.pinimg.com/originals/be/df/c7/bedfc7e2327780e3a0a24010350c3232.jpg)
# #6 파일 다운로드가 완료되었습니다.
# #7 이미지 다운로드 (http://cfile224.uf.daum.net/image/99A81F4D5C0A3D292A988F)
# #7 파일 다운로드가 완료되었습니다.
# #8 이미지 다운로드 (http://cfs3.tistory.com/upload_control/download.blog?fhandle=YmxvZzM1MTEyQGZzMy50aXN0b3J5LmNvbTovYXR0YWNoLzEvMTE4LkpQRw%3D%3D)
# #8 파일 다운로드가 완료되었습니다.
# #9 이미지 다운로드 (http://cfs2.tistory.com/upload_control/download.blog?fhandle=YmxvZzM1MTEyQGZzMi50aXN0b3J5LmNvbTovYXR0YWNoLzEvMTIxLkpQRw%3D%3D)
# #9 파일 다운로드가 완료되었습니다.
# #10 이미지 다운로드 (http://cfile205.uf.daum.net/image/142E9C1A4CC40E64092BC2)
# #10 파일 다운로드가 완료되었습니다.
# #11 이미지 다운로드 (https://t1.daumcdn.net/cfile/blog/23324F4E55D903CC26)
# #11 파일 다운로드가 완료되었습니다.
# #12 이미지 다운로드 (https://img1.daumcdn.net/thumb/R720x0/?fname=https:%2F%2Ft1.daumcdn.net%2Fliveboard%2Fholapet%2Ffc863f842c2344408609568cdb2a2852.jpg)
# #12 파일 다운로드가 완료되었습니다.
# #13 이미지 다운로드 (http://cfile217.uf.daum.net/image/151EFE504E16DF0C1FA3AC)
# #13 파일 다운로드가 완료되었습니다.
# #14 이미지 다운로드 (https://img.huffingtonpost.com/asset/5d8134e32300001005569b44.jpeg?ops=1200_630)
# [Error] Invalid image, not saving https://img.huffingtonpost.com/asset/5d8134e32300001005569b44.jpeg?ops=1200_630
# [Info] Issue getting: https://img.huffingtonpost.com/asset/5d8134e32300001005569b44.jpeg?ops=1200_630
# [Error] No active exception to reraise
# #14 이미지 다운로드 (http://pds4.egloos.com/pds/200704/14/66/c0020366_06041523.jpg)
# #14 파일 다운로드가 완료되었습니다.
# #15 이미지 다운로드 (http://cfile216.uf.daum.net/image/251F0A4851FA94250FDCCF)
# #15 파일 다운로드가 완료되었습니다.
# #16 이미지 다운로드 (https://img.seoul.co.kr/img/upload/2020/06/02/SSI_20200602131748.jpg)
# #16 파일 다운로드가 완료되었습니다.
# #17 이미지 다운로드 (https://dimg.donga.com/a/660/0/90/5/ugc/CDB/SODA/Article/58/cf/3e/bb/58cf3ebb048ad2738de6.png)
# #17 파일 다운로드가 완료되었습니다.
# #18 이미지 다운로드 (http://cfile230.uf.daum.net/image/132E6F3550B5D9811E174E)
# #18 파일 다운로드가 완료되었습니다.
# #19 이미지 다운로드 (https://img.huffingtonpost.com/asset/5b4559c91a00002700ce3cf7.jpeg?cache=IJqWlNGmog&amp;ops=scalefit_630_noupscale)
# [Error] Invalid image, not saving https://img.huffingtonpost.com/asset/5b4559c91a00002700ce3cf7.jpeg?cache=IJqWlNGmog&amp;ops=scalefit_630_noupscale
# [Info] Issue getting: https://img.huffingtonpost.com/asset/5b4559c91a00002700ce3cf7.jpeg?cache=IJqWlNGmog&amp;ops=scalefit_630_noupscale
# [Error] No active exception to reraise
# #19 이미지 다운로드 (http://animal.memozee.com/ArchHAN02/1150869870.jpg)
# #19 파일 다운로드가 완료되었습니다.
# #20 이미지 다운로드 (https://i.ytimg.com/vi/WROhpdrS4WY/maxresdefault.jpg)
# #20 파일 다운로드가 완료되었습니다.
# #21 이미지 다운로드 (https://pbs.twimg.com/profile_images/419173455011930112/_Aa0jfm-_400x400.jpeg)
# #21 파일 다운로드가 완료되었습니다.
# #22 이미지 다운로드 (http://cfs3.tistory.com/upload_control/download.blog?fhandle=YmxvZzM1MTEyQGZzMy50aXN0b3J5LmNvbTovYXR0YWNoLzEvMTkwLmpwZw%3D%3D)
# #22 파일 다운로드가 완료되었습니다.
# #23 이미지 다운로드 (http://www.wooripuppy.co.kr/data/file/puppy2/3740095211_wqCtV0ZH_20161106_132609.jpg)
# #23 파일 다운로드가 완료되었습니다.
# #24 이미지 다운로드 (https://img.animalplanet.co.kr/thumbnail/2020/05/27/2000/9212187w6mi9ab7cqf4r.jpg)
# #24 파일 다운로드가 완료되었습니다.
# #25 이미지 다운로드 (https://t1.daumcdn.net/cfile/blog/142472495088B6690E)
# #25 파일 다운로드가 완료되었습니다.
# #26 이미지 다운로드 (https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Fblog%2F18057A1A4AFFBA1C84)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Fblog%2F18057A1A4AFFBA1C84
# [Error] HTTP Error 403: Forbidden
# #26 이미지 다운로드 (https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F230D063957D4F5211B)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F230D063957D4F5211B
# [Error] HTTP Error 403: Forbidden
# #26 이미지 다운로드 (https://pbs.twimg.com/media/Dm_4qjFU4AAaqR4.jpg)
# #26 파일 다운로드가 완료되었습니다.
# #27 이미지 다운로드 (https://i.ytimg.com/vi/DIwhJmwNPRI/maxresdefault.jpg)
# #27 파일 다운로드가 완료되었습니다.
# #28 이미지 다운로드 (https://3.bp.blogspot.com/-DHMtCCAfQQE/WlDcqtTh03I/AAAAAAAAEtM/dRT3S2mKBsM6HeHb41je3835SvBHEyRSQCLcBGAs/s1600/15.jpg)
# #28 파일 다운로드가 완료되었습니다.
# #29 이미지 다운로드 (http://cfile27.uf.tistory.com/image/251C1D48542776090B84A9)
# #29 파일 다운로드가 완료되었습니다.
# #30 이미지 다운로드 (https://i.ytimg.com/vi/rG_4xvZCgS0/maxresdefault.jpg)
# #30 파일 다운로드가 완료되었습니다.
# #31 이미지 다운로드 (http://digitalchosun.dizzo.com/site/data/img_dir/2018/01/09/2018010911176_0.jpg)
# #31 파일 다운로드가 완료되었습니다.
# #32 이미지 다운로드 (http://cfile213.uf.daum.net/image/192B0B154A77814C72863F)
# #32 파일 다운로드가 완료되었습니다.
# #33 이미지 다운로드 (http://postfiles1.naver.net/20160514_208/easternrosella_1463205726963cnGyR_JPEG/%C1%F8%B5%BE%B0%B3.jpg?type=w1)
# #33 파일 다운로드가 완료되었습니다.
# #34 이미지 다운로드 (http://postfiles16.naver.net/20100216_63/wpwnalska_1266247004671FlHkG_jpg/dsc_0073_wpwnalska.jpg?type=w1)
# #34 파일 다운로드가 완료되었습니다.
# #35 이미지 다운로드 (http://cfile226.uf.daum.net/image/241C7A3A5291B9910DE533)
# #35 파일 다운로드가 완료되었습니다.
# #36 이미지 다운로드 (https://t1.daumcdn.net/cfile/blog/21534D445361DF932A)
# #36 파일 다운로드가 완료되었습니다.
# [Info] Done. Downloaded 36 images.
# [Info] Indexing page: 2
# [Info] Indexed 35 Images on Page 2.
# ===============================================
# #37 이미지 다운로드 (https://lh3.googleusercontent.com/-NdCcPkRm0lY/W0YBeihxd9I/AAAAAAADAV0/fwD36p2ucp85ciwNT5zDmoaa2wcxKqxrQCHMYCw/s0/068671d19df8a7e6533af3253ada1b27651e7ab6.jpg)
# #37 파일 다운로드가 완료되었습니다.
# #38 이미지 다운로드 (http://5taku.com/uploaded/board/2015/08/26/o_19timah9i7md4pj19n1sqk1sapv.jpg)
# #38 파일 다운로드가 완료되었습니다.
# #39 이미지 다운로드 (https://image.ytn.co.kr/general/jpg/2020/0614/202006141404116144_t.jpg)
# #39 파일 다운로드가 완료되었습니다.
# #40 이미지 다운로드 (https://img1.daumcdn.net/thumb/R720x0/?fname=https:%2F%2Ft1.daumcdn.net%2Fliveboard%2Fholapet%2Fc5ff09c7aa1d48a99554d3442ff8462c.jpg)
# #40 파일 다운로드가 완료되었습니다.
# ===============================================
# [Info] Done. Downloaded 40 images.
# [Train Dataset] image_32.jpg
# [Train Dataset] image_17.png
# [Train Dataset] image_11.jpg
# [Train Dataset] image_34.jpg
# [Train Dataset] image_30.jpg
# [Train Dataset] image_23.jpg
# [Train Dataset] image_27.jpg
# [Train Dataset] image_16.jpg
# [Train Dataset] image_21.jpeg
# [Train Dataset] image_10.jpg
# [Train Dataset] image_1.jpg
# [Train Dataset] image_33.jpg
# [Train Dataset] image_31.jpg
# [Train Dataset] image_7.jpg
# [Train Dataset] image_6.jpg
# [Train Dataset] image_20.jpg
# [Train Dataset] image_39.jpg
# [Train Dataset] image_12.jpg
# [Train Dataset] image_4.jpg
# [Train Dataset] image_29.jpg
# [Train Dataset] image_37.jpg
# [Train Dataset] image_15.jpg
# [Train Dataset] image_28.jpg
# [Train Dataset] image_5.jpg
# [Train Dataset] image_25.jpg
# [Train Dataset] image_13.jpg
# [Train Dataset] image_26.jpg
# [Train Dataset] image_19.jpg
# [Train Dataset] image_22.jpg
# [Train Dataset] image_40.jpg
# [Test Dataset] image_35.jpg
# [Test Dataset] image_36.jpg
# [Test Dataset] image_14.jpg
# [Test Dataset] image_38.jpg
# [Test Dataset] image_3.jpg
# [Test Dataset] image_8.jpg
# [Test Dataset] image_18.jpg
# [Test Dataset] image_2.jpg
# [Test Dataset] image_9.jpg
# [Test Dataset] image_24.jpg

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
from torchvision import datasets, models, transforms

import numpy as np
import time

device= torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# 데이터셋을 불러올 때 사용할 변형(transformation) 객체 정의
transforms_train=transforms.Compose([
    transforms.Resize((224,224)),
    transforms.RandomHorizontalFlip(), # 데이터 증진(augmentation)
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224 , 0.225]) # 정규화(normalization)

])
transforms_test=transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224 , 0.225])

])

data_dir='./custom_dataset'
train_datasets= datasets.ImageFolder(os.path.join(data_dir, 'train'), transforms_train)
test_datasets=datasets.ImageFolder(os.path.join(data_dir,'test'), transforms_test)

train_dataloader=torch.utils.data.DataLoader(train_datasets, batch_size=4, shuffle=True, num_workers=4)
test_dataloader=torch.utils.data.DataLoader(test_datasets, batch_size=4, shuffle=True, num_workers=4)

print('학습 데이터셋 크기:', len(train_datasets))
print('테스트 데이터셋 크기:', len(test_datasets))

class_names = train_datasets.classes
print('클래스:',class_names)
# Out:
# 학습 데이터셋 크기: 100
# 테스트 데이터셋 크기: 32
# 클래스: ['말티즈', '시츄', '진돗개']
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
def imshow(input, title):
  input=input.numpy().transpose((1,2,0))
  # 이미지 정규화 해제하기
  mean=np.array([0.485,0.456,0.406])
  std=np.array([0.229,0.224,0.225])

  input= std * input +mean
  input=np.clip(input,0,1)

  plt.imshow(input)
  plt.title(title)
  plt.show()

# 학습 데이터를 배치 단위로 불러오기
iterator=iter(train_dataloader)

# 현재 배치를 이용해 격자 형태의 이미지를 만들어 시각화
inputs, classes =next(iterator)
out=torchvision.utils.make_grid(inputs)
imshow(out, title=[class_names[x] for x in classes])
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
model = models.resnet34(pretrained= True)
num_features = model.fc.in_features
# 전이 학습(transfer learning): 모델의 출력 뉴런 수를 3개로 교체하여 마지막 레이어 다시 학습
model.fc=nn.Linear(num_features, 3)
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum =0.9)

# %%
num_epochs = 50
model.train()
start_time = time.time()

# 전체 반복(epoch) 수 만큼 반복하며
for epoch in range(num_epochs):
  running_loss =0.
  running_corrects =0

  # 배치 단위로 학습 데이터 불러오기  
  for inputs, labels in train_dataloader:
    inputs = inputs.to(device)
    labels = labels.to(device)

    # 모델에 입력(forward)하고 결과 계산
    optimizer.zero_grad()
    outputs = model(inputs)
    _, preds = torch.max(outputs, 1)
    loss = criterion(outputs, labels)

    # 역전파를 통해 기울기(gradient) 계산 및 학습 진행
    loss.backward()
    optimizer.step()

    running_loss +=loss.item() * inputs.size(0)
    running_corrects += torch.sum(preds == labels.data)
    
  epoch_loss = running_loss / len(train_datasets)
  epoch_acc = running_corrects / len(train_datasets) * 100.

  print('#{} Loss : {:.4f} Acc : {:.4f}% Time: {:.4f}s'.format(epoch, epoch_loss, epoch_acc, time.time()-start_time))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# #0 Loss : 0.8944 Acc : 58.0000% Time: 4.1754s
# #1 Loss : 0.3290 Acc : 88.0000% Time: 8.2324s
# #2 Loss : 0.1950 Acc : 93.0000% Time: 12.1235s
# #3 Loss : 0.2271 Acc : 91.0000% Time: 16.1819s
# #4 Loss : 0.2091 Acc : 92.0000% Time: 20.5628s
# #5 Loss : 0.2248 Acc : 90.0000% Time: 24.6799s
# #6 Loss : 0.1277 Acc : 95.0000% Time: 28.8290s
# #7 Loss : 0.2623 Acc : 93.0000% Time: 33.1061s
# #8 Loss : 0.0908 Acc : 98.0000% Time: 36.9775s
# #9 Loss : 0.2553 Acc : 91.0000% Time: 41.0795s
# #10 Loss : 0.1889 Acc : 94.0000% Time: 45.1385s
# #11 Loss : 0.2574 Acc : 93.0000% Time: 49.1928s
# #12 Loss : 0.1917 Acc : 94.0000% Time: 53.2131s
# #13 Loss : 0.1025 Acc : 98.0000% Time: 57.3705s
# #14 Loss : 0.0624 Acc : 97.0000% Time: 61.2865s
# #15 Loss : 0.1759 Acc : 94.0000% Time: 65.3972s
# #16 Loss : 0.1431 Acc : 96.0000% Time: 69.3376s
# #17 Loss : 0.2635 Acc : 91.0000% Time: 73.5615s
# #18 Loss : 0.1987 Acc : 94.0000% Time: 77.6634s
# #19 Loss : 0.2205 Acc : 93.0000% Time: 81.5668s
# #20 Loss : 0.3026 Acc : 92.0000% Time: 85.7149s
# #21 Loss : 0.0461 Acc : 98.0000% Time: 89.7323s
# #22 Loss : 0.0280 Acc : 99.0000% Time: 93.7194s
# #23 Loss : 0.2547 Acc : 94.0000% Time: 97.6049s
# #24 Loss : 0.0855 Acc : 96.0000% Time: 101.7045s
# #25 Loss : 0.1898 Acc : 93.0000% Time: 105.7985s
# #26 Loss : 0.0783 Acc : 97.0000% Time: 110.0358s
# #27 Loss : 0.1555 Acc : 95.0000% Time: 113.9191s
# #28 Loss : 0.3012 Acc : 94.0000% Time: 118.2215s
# #29 Loss : 0.0544 Acc : 99.0000% Time: 122.3477s
# #30 Loss : 0.2146 Acc : 95.0000% Time: 126.4995s
# #31 Loss : 0.1274 Acc : 96.0000% Time: 130.5776s
# #32 Loss : 0.0143 Acc : 100.0000% Time: 134.6799s
# #33 Loss : 0.1317 Acc : 97.0000% Time: 138.9072s
# #34 Loss : 0.0251 Acc : 100.0000% Time: 143.0496s
# #35 Loss : 0.0070 Acc : 100.0000% Time: 146.8458s
# #36 Loss : 0.0862 Acc : 97.0000% Time: 151.0665s
# #37 Loss : 0.0327 Acc : 99.0000% Time: 155.0797s
# #38 Loss : 0.0231 Acc : 99.0000% Time: 159.0827s
# #39 Loss : 0.1880 Acc : 93.0000% Time: 163.1276s
# #40 Loss : 0.0326 Acc : 99.0000% Time: 167.0560s
# #41 Loss : 0.0493 Acc : 99.0000% Time: 170.9970s
# #42 Loss : 0.2262 Acc : 91.0000% Time: 175.0135s
# #43 Loss : 0.2914 Acc : 92.0000% Time: 179.1413s
# #44 Loss : 0.0370 Acc : 98.0000% Time: 183.2167s
# #45 Loss : 0.1298 Acc : 97.0000% Time: 187.4002s
# #46 Loss : 0.3737 Acc : 93.0000% Time: 191.5422s
# #47 Loss : 0.2612 Acc : 95.0000% Time: 195.6427s
# #48 Loss : 0.1057 Acc : 99.0000% Time: 200.1172s
# #49 Loss : 0.0136 Acc : 100.0000% Time: 204.1799s

# %%
model.eval()
start_time=time.time()

with torch.no_grad():
    running_loss=0.
    running_corrects =0
    for inputs, labels in test_dataloader:
        inputs =inputs.to(device)
        labels =labels.to(device) 

        outputs=model(inputs)
        _,preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

        print(f'[예측 결과: {class_names[preds[0]]}] (실제 정답: {class_names[labels.data[0]]})')
        imshow(inputs.cpu().data[0], title= '예측 결과 : ' +class_names[preds[0]])
        
    epoch_loss = running_loss / len(test_datasets)
    epoch_acc = running_corrects / len(test_datasets) * 100.
    print('[Test Phase] Loss : {:.4f} Acc: {:.4f}% Time: {:.4f}s'.format(epoch_loss, epoch_acc, time.time()-start_time))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [예측 결과: 진돗개] (실제 정답: 진돗개)
# [예측 결과: 시츄] (실제 정답: 시츄)
# [예측 결과: 진돗개] (실제 정답: 진돗개)
# [예측 결과: 말티즈] (실제 정답: 말티즈)
# [예측 결과: 말티즈] (실제 정답: 말티즈)
# [예측 결과: 시츄] (실제 정답: 시츄)
# [예측 결과: 시츄] (실제 정답: 시츄)
# [예측 결과: 시츄] (실제 정답: 시츄)
# [Test Phase] Loss : 0.0656 Acc: 96.8750% Time: 3.7307s

# %%
# 테스트용 이미지 다운로드하기
# !wget https://ww.namu.la/s/3123c09c7aeb0bec2d151c8cc694f3c6b9d54c00c540a338acb413b35ae57bbf37ab000b0e39b15f1533d29ffffca3b36279261f930d18b9b967f7f201d6abe900e048c209dabc4d06efa2198541dceccfc60da3762b1ed1dc216a13a02af525 -O test_image.jpg
# Out:
# --2022-03-26 07:26:31--  https://ww.namu.la/s/3123c09c7aeb0bec2d151c8cc694f3c6b9d54c00c540a338acb413b35ae57bbf37ab000b0e39b15f1533d29ffffca3b36279261f930d18b9b967f7f201d6abe900e048c209dabc4d06efa2198541dceccfc60da3762b1ed1dc216a13a02af525
# Resolving ww.namu.la (ww.namu.la)... 104.19.234.61, 104.19.233.61, 2606:4700::6813:ea3d, ...
# Connecting to ww.namu.la (ww.namu.la)|104.19.234.61|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 487524 (476K) [image/png]
# Saving to: ‘test_image.jpg’
#
# test_image.jpg      100%[===================>] 476.10K  --.-KB/s    in 0.04s
#
# 2022-03-26 07:26:31 (12.7 MB/s) - ‘test_image.jpg’ saved [487524/487524]

# %%
from PIL import Image

image = Image.open('test_image.jpg').convert('RGB')
image= transforms_test(image).unsqueeze(0).to(device)

with torch.no_grad():
    outputs =model(image)
    _, preds = torch.max(outputs, 1)
    imshow(image.cpu().data[0], title='예측 결과: ' + class_names[preds[0]])

# %%
# !pip install flask-ngrok
# Out:
# Requirement already satisfied: flask-ngrok in /usr/local/lib/python3.7/dist-packages (0.0.25)
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (1.1.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (2.23.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (2.11.3)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (7.1.2)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.1.0)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=0.8->flask-ngrok) (2.0.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (2021.10.8)

# %%
import io 
from flask_ngrok import run_with_ngrok
from flask import Flask, jsonify, request 
from PIL import Image

def get_prediction(image_bytes):
    image=Image.open(io.BytesIO(image_bytes))
    image=transforms_test(image).unsqueeze(0).to(device)

    with torch.no_grad():
        outputs = model(image)
        _, preds = torch.max(outputs, 1)
        imshow(image.cpu().data[0], title='예측 결과: ' +class_names[preds[0]])

    return class_names[preds[0]]

app= Flask(__name__)

@app.route('/', methods=['POST'])
def predict():
    if request.method=='POST':
        # 이미지 바이트 데이터 받아오기
        file=request.files['file']
        image_bytes=file.read()

        # 분류 결과 확인 및 클라이언트에게 결과 반환
        class_name=get_prediction(image_bytes= image_bytes)
        print("결과:",{'class_name' : class_name})
        return jsonify({'class_name': class_name})

# %%
run_with_ngrok(app)
app.run()
